# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
from sqlalchemy import create_engine
! pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in /opt/anaconda3/lib/python3.9/site-packages (2.9.3)

# %% [markdown]
# # Extract CSVs into DataFrames

# %%
#Path to Salary CSV file 
salary_path = "Data/salary_potential.csv"

#Read the CSV file and create dataframe
salary_data = pd.read_csv(salary_path)

salary_data.head()
# Out:
#    rank                                 name state_name  early_career_pay  \
# 0     1                    Auburn University    Alabama             54400
# 1     2  University of Alabama in Huntsville    Alabama             57500
# 2     3            The University of Alabama    Alabama             52300
# 3     4                  Tuskegee University    Alabama             54500
# 4     5                   Samford University    Alabama             48400
#
#    mid_career_pay  make_world_better_percent  stem_percent
# 0          104500                       51.0            31
# 1          103900                       59.0            45
# 2           97400                       50.0            15
# 3           93500                       61.0            30
# 4           90500                       52.0             3

# %%
#Path to Tuition CSV file 
tuition_path = "Data/tuition_cost.csv"

#Read the CSV file and create dataframe
tuition_data = pd.read_csv(tuition_path)

tuition_data.head()
# Out:
#                                    name       state state_code        type  \
# 0                Aaniiih Nakoda College     Montana         MT      Public
# 1          Abilene Christian University       Texas         TX     Private
# 2  Abraham Baldwin Agricultural College     Georgia         GA      Public
# 3                       Academy College   Minnesota         MN  For Profit
# 4             Academy of Art University  California         CA  For Profit
#
#   degree_length  room_and_board  in_state_tuition  in_state_total  \
# 0        2 Year             NaN              2380            2380
# 1        4 Year         10350.0             34850           45200
# 2        2 Year          8474.0              4128           12602
# 3        2 Year             NaN             17661           17661
# 4        4 Year         16648.0             27810           44458
#
#    out_of_state_tuition  out_of_state_total
# 0                  2380                2380
# 1                 34850               45200
# 2                 12550               21024
# 3                 17661               17661
# 4                 27810               44458

# %% [markdown]
# # Transform DataFrames

# %%
#Clean up the dataframe
salary= salary_data.drop(columns= ["rank","stem_percent","make_world_better_percent"])
salary.head()
# Out:
#                                   name state_name  early_career_pay  \
# 0                    Auburn University    Alabama             54400
# 1  University of Alabama in Huntsville    Alabama             57500
# 2            The University of Alabama    Alabama             52300
# 3                  Tuskegee University    Alabama             54500
# 4                   Samford University    Alabama             48400
#
#    mid_career_pay
# 0          104500
# 1          103900
# 2           97400
# 3           93500
# 4           90500

# %%
#Clean up the dataframe
tuition_data_clean = tuition_data.drop(columns= ["in_state_total","out_of_state_tuition","state_code","room_and_board"])

tuition_frame= tuition_data_clean.dropna()

tuition = tuition_frame[tuition_frame['name'].isin(salary['name'])]
tuition.head()
# Out:
#                                        name     state     type degree_length  \
# 5                    Adams State University  Colorado   Public        4 Year
# 10  Adventist University of Health Sciences   Florida  Private        4 Year
# 11                      Agnes Scott College   Georgia  Private        4 Year
# 16                 Alabama State University   Alabama   Public        4 Year
# 19                Alaska Pacific University    Alaska  Private        4 Year
#
#     in_state_tuition  out_of_state_total
# 5               9440               29238
# 10             15150               19350
# 11             41160               53490
# 16             11068               24818
# 19             20830               28130

# %%
#Merge the salary and tuition df
sal_tuition = pd.merge(tuition, salary, on='name')
sal_tuition.drop(columns=["state"])
# Out:
#                                         name     type degree_length  \
# 0                     Adams State University   Public        4 Year
# 1    Adventist University of Health Sciences  Private        4 Year
# 2                        Agnes Scott College  Private        4 Year
# 3                   Alabama State University   Public        4 Year
# 4                  Alaska Pacific University  Private        4 Year
# ..                                       ...      ...           ...
# 723          Worcester Polytechnic Institute  Private        4 Year
# 724                        Xavier University  Private        4 Year
# 725           Xavier University of Louisiana  Private        4 Year
# 726                          Yale University  Private        4 Year
# 727                       Yeshiva University  Private        4 Year
#
#      in_state_tuition  out_of_state_total     state_name  early_career_pay  \
# 0                9440               29238       Colorado             44400
# 1               15150               19350        Florida             51600
# 2               41160               53490        Georgia             46000
# 3               11068               24818        Alabama             39800
# 4               20830               28130         Alaska             50300
# ..                ...                 ...            ...               ...
# 723             50530               65304  Massachusetts             73600
# 724             38530               51310           Ohio             51800
# 725             24488               33535      Louisiana             46700
# 726             53430               69430    Connecticut             70300
# 727             43500               55750       New-York             63500
#
#      mid_career_pay
# 0             81400
# 1             89800
# 2             83600
# 3             71500
# 4             90000
# ..              ...
# 723          135500
# 724           94000
# 725           88200
# 726          138300
# 727          112800
#
# [728 rows x 8 columns]

# %% [markdown]
# # Create database connection

# %%
rds_connection_string = "postgres:postgres@localhost:5432/salary_tuition"

engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# /var/folders/8v/9xz9_bk116j2sr6hpcb2xbxm0000gn/T/ipykernel_43031/4162273999.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['sal_tuition', 'salary', 'tuition']

# %% [markdown]
# # Load DataFrames into database

# %%
salary.to_sql(name='salary', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('SELECT * FROM salary', con = engine)
# Out:
#                                     name state_name  early_career_pay  \
# 0                      Auburn University    Alabama             54400
# 1    University of Alabama in Huntsville    Alabama             57500
# 2              The University of Alabama    Alabama             52300
# 3                    Tuskegee University    Alabama             54500
# 4                     Samford University    Alabama             48400
# ..                                   ...        ...               ...
# 930                   Viterbo University  Wisconsin             46800
# 931       Concordia University-Wisconsin  Wisconsin             46700
# 932     University of Wisconsin-Parkside  Wisconsin             46000
# 933  University of Wisconsin-River Falls  Wisconsin             47100
# 934                University of Wyoming    Wyoming             52400
#
#      mid_career_pay
# 0            104500
# 1            103900
# 2             97400
# 3             93500
# 4             90500
# ..              ...
# 930           81900
# 931           81600
# 932           81400
# 933           81300
# 934           98800
#
# [935 rows x 4 columns]

# %%
tuition.to_sql(name='tuition', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('SELECT * FROM tuition', con = engine)
# Out:
#                                         name          state     type  \
# 0                     Adams State University       Colorado   Public
# 1    Adventist University of Health Sciences        Florida  Private
# 2                        Agnes Scott College        Georgia  Private
# 3                   Alabama State University        Alabama   Public
# 4                  Alaska Pacific University         Alaska  Private
# ..                                       ...            ...      ...
# 723          Worcester Polytechnic Institute  Massachusetts  Private
# 724                        Xavier University           Ohio  Private
# 725           Xavier University of Louisiana      Louisiana  Private
# 726                          Yale University    Connecticut  Private
# 727                       Yeshiva University       New York  Private
#
#     degree_length  in_state_tuition  out_of_state_total
# 0          4 Year              9440               29238
# 1          4 Year             15150               19350
# 2          4 Year             41160               53490
# 3          4 Year             11068               24818
# 4          4 Year             20830               28130
# ..            ...               ...                 ...
# 723        4 Year             50530               65304
# 724        4 Year             38530               51310
# 725        4 Year             24488               33535
# 726        4 Year             53430               69430
# 727        4 Year             43500               55750
#
# [728 rows x 6 columns]

# %%
sal_tuition.to_sql(name='sal_tuition', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('SELECT * FROM sal_tuition', con = engine)
# Out:
#                                         name          state     type  \
# 0                     Adams State University       Colorado   Public
# 1    Adventist University of Health Sciences        Florida  Private
# 2                        Agnes Scott College        Georgia  Private
# 3                   Alabama State University        Alabama   Public
# 4                  Alaska Pacific University         Alaska  Private
# ..                                       ...            ...      ...
# 723          Worcester Polytechnic Institute  Massachusetts  Private
# 724                        Xavier University           Ohio  Private
# 725           Xavier University of Louisiana      Louisiana  Private
# 726                          Yale University    Connecticut  Private
# 727                       Yeshiva University       New York  Private
#
#     degree_length  in_state_tuition  out_of_state_total     state_name  \
# 0          4 Year              9440               29238       Colorado
# 1          4 Year             15150               19350        Florida
# 2          4 Year             41160               53490        Georgia
# 3          4 Year             11068               24818        Alabama
# 4          4 Year             20830               28130         Alaska
# ..            ...               ...                 ...            ...
# 723        4 Year             50530               65304  Massachusetts
# 724        4 Year             38530               51310           Ohio
# 725        4 Year             24488               33535      Louisiana
# 726        4 Year             53430               69430    Connecticut
# 727        4 Year             43500               55750       New-York
#
#      early_career_pay  mid_career_pay
# 0               44400           81400
# 1               51600           89800
# 2               46000           83600
# 3               39800           71500
# 4               50300           90000
# ..                ...             ...
# 723             73600          135500
# 724             51800           94000
# 725             46700           88200
# 726             70300          138300
# 727             63500          112800
#
# [728 rows x 9 columns]
